# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import math
from numpy.lib import scimath

# %%
t = np.arange(1, 110, 0.2)
#print(t)

#factorial = np.vectorize(math.factorial)
#print(factorial(t))
#plt.plot(t, factorial(t), label='n!')

plt.plot(t, 2**t, label='2^n')
plt.plot(t, t**2, label='n^2')
plt.plot(t, n * np.log(t), label='n log n')
plt.plot(t, t, label='n')
plt.plot(t, np.log(t), label='log n')
plt.plot(t,  np.array([1 for i in range(0, t.size)]), 'r', label='1')

plt.legend()
#plt.yscale('log', basey=10)
plt.ylim([0, 40])
#plt.xlim([1, 10])
plt.show()
